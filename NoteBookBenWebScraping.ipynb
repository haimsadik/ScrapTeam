# %% [markdown]
# # WebScraping Notebook Ben

# %%
#On télecharge les packages dont on va avoir besoin
import selenium #pip install selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By  
import time
#BeautifulSoup , Request et Pandas
import urllib
import bs4
from urllib import request
import pandas 
#pour les graphiques
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
path_to_web_driver = "/Users/SADIK/Desktop/PythonWebScrap/chromedriver"
browser = webdriver.Chrome(path_to_web_driver)
browser.get('http://www.matchendirect.fr/resultat-foot-21-01-2018/')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-65-93110ac774a2> in <module>()
#       1 path_to_web_driver = "/Users/SADIK/Desktop/PythonWebScrap/chromedriver"
#       2 browser = webdriver.Chrome(path_to_web_driver)
# ----> 3 browser.get('http://www.matchendirect.fr/resultat-foot-21-01-2018/')
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     322         Loads a web page in the current browser session.
#     323         """
# --> 324         self.execute(Command.GET, {'url': url})
#     325
#     326     @property
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     310         response = self.command_executor.execute(driver_command, params)
#     311         if response:
# --> 312             self.error_handler.check_response(response)
#     313             response['value'] = self._unwrap_value(
#     314                 response.get('value', None))
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     235         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     236             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 237         raise exception_class(message, screen, stacktrace)
#     238
#     239     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: disconnected: received Inspector.detached event
#   (Session info: chrome=56.0.2924.87)
#   (Driver info: chromedriver=2.24.417412 (ac882d3ce7c0d99292439bf3405780058fcca0a6),platform=Mac OS X 10.13.2 x86_64)

# %%
#Lecture de la page 

#On récupère le texte et l'id de la page suivante, qui apparait comme standardisé
lien='http://www.matchendirect.fr/resultat-foot-21-01-2018/'
request_text = request.urlopen(lien).read()
page = bs4.BeautifulSoup(request_text, "lxml")
# request_text c'est trop dégueu
#  page.find('div', {'class':'pagination'}).find('a')['href']
# Out:
# <!DOCTYPE html>
# <html lang="fr">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Resultat foot du dimanche 21 janvier 2018 (1201 matchs)</title>
# <meta content="resultat foot, resultats foot, resultat football, resultats football, resultat, resultats, foot, football, 21-01-2018" name="keywords"/>
# <meta content="Calendrier des matchs de football a suivre en direct le dimanche 21 janvier 2018 (1201 matchs)" name="description"/>
# <meta content="1a9bd6d3b4223b5a" name="y_key"/>
# <meta content="H30g3QlZj0Cf7XMTWcstfhHrSFytUrjs3MAQ9SI7M0c=" name="verify-v1"/>
# <meta content="249oP_EyqS1fiKYsjaAtY2w1s6AGlWtv_EcO2ed42Q0" name="google-site-verification"/>
# <meta content="app-id=370406465" name="apple-itunes-app"/>
# <meta content="app-id=com.activaweb.matchendirect" name="google-play-app"/>
# <meta content="371409472768" property="fb:app_id"/>
# <meta content="779024660" property="fb:admins"/>
# <meta content="sport" property="og:type"/>
# <meta content="MatchEnDirect.fr" property="og:site_name"/>
# <meta content="http://www.matchendirect.fr/resultat-foot-21-01-2018/" property="og:url"/>
# <meta content="Resultat foot du dimanche 21 janvier 2018 (1201 matchs)" property="og:title"/>
# <meta content="Calendrier des matchs de football a suivre en direct le dimanche 21 janvier 2018 (1201 matchs)" property="og:description"/>
# <meta content="http://www.matchendirect.fr/image/commun/og-image-512.png" property="og:image"/>
# <meta content="git" name="version"/>
# <link href="https://ajax.googleapis.com/ajax/libs/jqueryui/1.12.1/themes/smoothness/jquery-ui.css" rel="stylesheet"/>
# <link href="/html_include/css/bootstrap.min.css?v411" rel="stylesheet"/>
# <link href="/html_include/css/bootstrap-theme.min.css?v411" rel="stylesheet"/>
# <link href="/html_include/css/commun-responsive-lessphp.css?v411" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" integrity="sha384-wvfXpqpZZVQGK6TAh5PVlGOfQNHSoD2xbE+QkPxCAFlNEevoEH3Sl0sibVcOQVnN" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Montserrat" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Lato" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Exo+2" rel="stylesheet" type="text/css"/>
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#                 var $data = {"connected":false,"blueKaiParams":{"page_type":"results","page_primary_tag":"Football"}};
#                 </script>
# <script src="/html_include/js/commun_top.js?v411"></script>
# <script>
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-9126188-1', 'auto');
# ga('require', 'displayfeatures');
# ga('send', 'pageview');
# </script>
# </head>
# <body class="nbCol3 football ">
# <div id="fb-root"></div>
# <nav class="navbar navbar-inverse navbar-static-top">
# <div class="container">
# <div class="navbar-header">
# <button aria-controls="navbar" aria-expanded="false" class="navbar-toggle collapsed" data-target="#navbar" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <a class="navbar-brand" href="/" title="MatchEnDirect.fr"><img height="35" src="/image/commun/logo/match-en-direct-football-live.png" width="130"/></a>
# <span class="bloc_connexion"></span>
# </div>
# <div class="navbar-collapse collapse" id="navbar">
# <ul class="nav navbar-nav" id="menu_sport">
# <li class=" active"><a href="/">Football <span class="sr-only">(current)</span></a></li>
# <li class=""><a href="/basket/">Basketball</a></li>
# <li class=""><a href="/tennis/">Tennis</a></li>
# <li class=""><a href="/rugby/">Rugby</a></li>
# <li class=""><a href="/handball/">Handball</a></li>
# <li class=""><a href="/hockey/">Hockey</a></li>
# <li class="forums"><a href="/forum/">Forums</a></li>
# </ul>
# <span class="bMore"><span aria-hidden="true" class="glyphicon glyphicon-plus" title="Afficher le menu"></span></span>
# <div class="blocSearchConn">
# <form action="/recherche/" class="input-group blocrond" method="post">
# <input class="form-control" name="f_motcle" placeholder="Rechercher..." type="text" value=""/>
# <span class="input-group-addon">
# <button title="Rechercher" type="submit">
# <span class="glyphicon glyphicon-search"></span>
# </button>
# </span>
# </form>
# <span class="bloc_connexion"></span>
# </div>
# </div>
# </div>
# </nav>
# <nav class="navbar2 navbar-inverse">
# <div class="container">
# <ul class="nav navbar-nav" id="sous_menu_sport">
# <li><a href="/resultat-foot-22-01-2018/" title="Consultez les résultats d'hier">Hier</a></li>
# <li><a href="/" title="Suivez les matchs du jour">Aujourd'hui</a></li>
# <li><a href="/resultat-foot-24-01-2018/" title="Découvrez le programme de demain">Demain</a></li>
# <li><a href="/live-score/" title="Suivez les matchs en direct">En direct <span class="badge">2</span></a></li>
# <li class="pariez1"><a href="/tux/navigation/parier/pmu.html" rel="nofollow" target="_blank" title="Parier">Parier</a></li>
# <li class="worldcup"><a href="/monde/coupe-du-monde/" title="Coupe du monde 2018">Coupe du monde</a></li>
# <li><a href="/selection/" title="Sélectionnez vos matchs">Mes matchs</a></li>
# <li><a href="/pronostics/" title="Concours de pronostics">Concours<span class="menuconcours"> de pronostics</span></a></li>
# <li class="pariez2"><a href="/tux/navigation/parier/pmu.html" rel="nofollow" target="_blank" title="Parier">Parier</a></li>
# </ul>
# <div class="navAd"><a href="/tux/navigation/promo/pmu.html" target="_blank"><img border="0" src="/image/bookmaker/PMU-Bouton-LTV-h32.png"/></a>
# <img height="0" src="https://eule1.pmu.fr/dynview/pmu/pix.gif?eaf-publisher=LTVSPORTMATCHENDIRECT_MATCHENDIRECT&amp;eaf-name=LTVSPORTMATCHENDIRECT_MATCHENDIRECT_2010_WEB_AFF_LTV&amp;eaf-creative=FID_S_DESKTOP_LTV2017_TEXTE&amp;eaf-creativetype=TEXTE&amp;eseg-name=ia-affilie&amp;eseg-item=a_304b_TEXTEc_aid&amp;eaf-mediaplan=2010_WEB_AFF_LTV&amp;ea-rnd=[RANDOM]" width="0"/>
# </div>
# </div>
# </nav>
# <div class="container" id="jDisplayMenu">
# <div class="text-center jMenuDown">
# <span aria-hidden="true" class="glyphicon glyphicon-menu-down mg"></span>    <a class="btn" href="javascript:void(0);">Afficher le menu</a>    <span aria-hidden="true" class="glyphicon glyphicon-menu-down mr"></span>
# </div>
# <div class="text-center jMenuUp">
# <span aria-hidden="true" class="glyphicon glyphicon-menu-up mg"></span>    <a class="btn" href="javascript:void(0);">Cacher le menu</a>    <span aria-hidden="true" class="glyphicon glyphicon-menu-up mr"></span>
# </div>
# </div>
# <div id="tux728x90"><script>getPub('728x90');</script></div>
# <div class="container main">
# <div class="row">
# <div class="col-md-8 col-lg-9 col-center col3">
# <div class="menu_haut">
# <ol class="breadcrumb">
# <li><a href="/"><span aria-hidden="true" class="glyphicon glyphicon-home"></span></a>   <a class="navHomeText" href="/">Match en direct</a></li><li><h1>Résultats football du dimanche 21 janvier 2018</h1></li>
# </ol>
# <div class="comments">
# <button class="btn btn-primary"><span aria-hidden="true" class="glyphicon glyphicon-comment"></span>    <div id="bloc_nb_commenaire"></div></button>
# </div>
# </div>
# <div class="row">
# <div class="col-lg-2 hidden-md hidden-xs hidden-sm col-left">
# <div class="menu">
# <span class="mtitle">COUPE DU MONDE</span>
# <a href="/monde/coupe-du-monde/" title="Coupe du Monde 2018"><span class="ico_competition ico_competition_72"></span> Russie 2018</a>
# <span class="mtitle">CHAMPIONNATS</span>
# <a href="/france/ligue-1/" title="Matchs de Ligue 1 en direct"><span class="ico_competition ico_competition_16"></span> Ligue 1</a>
# <a href="/france/ligue-2/" title="Matchs de Ligue 2 en direct"><span class="ico_competition ico_competition_17"></span> Ligue 2</a>
# <a href="/angleterre/barclays-premiership-premier-league/" title="Matchs de Premier League anglaise en direct"><span class="ico_competition ico_competition_8"></span> Premier League</a>
# <a href="/espagne/primera-division/" title="Matchs de Liga espagnol en direct"><span class="ico_competition ico_competition_7"></span> Liga</a>
# <a href="/italie/serie-a/" title="Matchs de Série A italienne en direct"><span class="ico_competition ico_competition_13"></span> Série A</a>
# <a href="/allemagne/bundesliga-1/" title="Matchs de Bundesliga allemande en direct"><span class="ico_competition ico_competition_9"></span> Bundesliga</a>
# <span class="mtitle">COUPES D'EUROPE</span>
# <a class="cl" href="/europe/ligue-des-champions-uefa/" title="Matchs en direct Ligue des Champions"><span class="ico_competition ico_competition_10"></span> Champions League</a>
# <a href="/europe/uefa-europa-league/" title="Matchs en direct Ligue Europa"><span class="ico_competition ico_competition_18"></span> Ligue Europa</a>
# <span class="mtitle">TOP PAYS</span>
# <a href="/france/" title="Matchs en direct France"><span class="ico_pays ico_pays_76"></span> France</a>
# <a href="/angleterre/" title="Matchs en direct Angleterre"><span class="ico_pays ico_pays_68"></span> Angleterre</a>
# <a href="/espagne/" title="Matchs en direct Espagne"><span class="ico_pays ico_pays_176"></span> Espagne</a>
# <a href="/italie/" title="Matchs en direct Italie"><span class="ico_pays ico_pays_100"></span> Italie</a>
# <a href="/allemagne/" title="Matchs en direct Allemagne"><span class="ico_pays ico_pays_80"></span> Allemagne</a>
# <a href="/portugal/" title="Matchs en direct Portugal"><span class="ico_pays ico_pays_156"></span> Portugal</a>
# <a href="/belgique/" title="Matchs en direct Belgique"><span class="ico_pays ico_pays_27"></span> Belgique</a>
# <a href="/pays-bas/" title="Matchs en direct Pays-Bas"><span class="ico_pays ico_pays_138"></span> Pays-Bas</a>
# <a href="/ecosse/" title="Matchs en direct Écosse"><span class="ico_pays ico_pays_165"></span> Écosse</a>
# <a href="/turquie/" title="Matchs en direct Turquie"><span class="ico_pays ico_pays_196"></span> Turquie</a>
# <a href="/algerie/" title="Matchs en direct Algérie"><span class="ico_pays ico_pays_10"></span> Algérie</a>
# <a href="/etats-unis/" title="Matchs en direct Etats-Unis"><span class="ico_pays ico_pays_203"></span> Etats-Unis</a>
# <a href="/bresil/" title="Matchs en direct Brésil"><span class="ico_pays ico_pays_35"></span> Brésil</a>
# <a href="/europe/" title="Matchs en direct Europe"><span class="ico_pays ico_pays_7"></span> Europe</a>
# <a href="/monde/" title="Matchs en direct Monde"><span class="ico_pays ico_pays_1"></span> Monde</a>
# <span class="mtitle">PARIS SPORTIFS</span>
# <a href="/tux/colgauche/menu/pmu.html" rel="nofollow" target="_blank" title="PMU"><span class="ico ico_book ico_book_pmu"></span> PMU</a>
# <a href="/tux/colgauche/menu/zebet.html" rel="nofollow" target="_blank" title="ZEbet"><span class="ico ico_book ico_book_zebet"></span> ZEbet</a>
# <a href="/tux/colgauche/menu/betclic.html" rel="nofollow" target="_blank" title="Betclic"><span class="ico ico_book ico_book_betclic"></span> Betclic</a>
# <span class="mtitle">TOUS LES PAYS</span>
# <a href="/afghanistan/" title="Matchs en direct Afghanistan"><span class="ico_pays ico_pays_8"></span> Afghanistan</a>
# <a href="/afrique-du-sud/" title="Matchs en direct Afrique du Sud"><span class="ico_pays ico_pays_175"></span> Afrique du Sud</a>
# <a href="/albanie/" title="Matchs en direct Albanie"><span class="ico_pays ico_pays_9"></span> Albanie</a>
# <a href="/algerie/" title="Matchs en direct Algérie"><span class="ico_pays ico_pays_10"></span> Algérie</a>
# <div id="menu_bloc_2" style="display: none;"></div>
# <a class="ico_btn_affplus afficher" href="javascript:void(0);" onclick="ouvrirMenu(this,'2')">Afficher plus</a>
# <span class="mtitle">INTERNATIONAL</span>
# <a href="/afrique/" title="Matchs en direct Afrique"><span class="ico_pays ico_pays_3"></span> Afrique</a>
# <a href="/amerique-du-nord/" title="Matchs en direct Amérique du Nord"><span class="ico_pays ico_pays_4"></span> Amérique du Nord</a>
# <a href="/amerique-du-sud/" title="Matchs en direct Amérique du Sud"><span class="ico_pays ico_pays_5"></span> Amérique du Sud</a>
# <a href="/asie/" title="Matchs en direct Asie"><span class="ico_pays ico_pays_2"></span> Asie</a>
# <a href="/oceanie/" title="Matchs en direct Océanie"><span class="ico_pays ico_pays_6"></span> Océanie</a>
# </div>
# <div class="colgauche_tux">
# <span class="mtitle">BONS PLANS</span>
# <ul class="list-group pave_book_conteneur">
# <li class="list-group-item">
# <a class="pave_book" href="/tux/colgauche/bonplan/pmu.html" rel="nofollow" target="_blank" title="PMU">100€ offerts*<br/><img alt="PMU" src="/image/bookmaker/h39-pmu.png?v3"/><br/><span class="txtpariez">Voir l'offre</span></a>
# </li>
# <li class="list-group-item">
# <a class="pave_book" href="/tux/colgauche/bonplan/zebet.html" rel="nofollow" target="_blank" title="ZEbet">150€ offerts*<br/><img alt="ZEbet" src="/image/bookmaker/h39-zebet.png?v3"/><br/><span class="txtpariez">Voir l'offre</span></a>
# </li>
# <li class="list-group-item">
# <a class="pave_book" href="/tux/colgauche/bonplan/betclic.html" rel="nofollow" target="_blank" title="Betclic">100€ offerts*<br/><img alt="Betclic" src="/image/bookmaker/h39-betclic.png?v3"/><br/><span class="txtpariez">Voir l'offre</span></a>
# </li>
# </ul>
# <span class="mtitle mtitleads">PUBLICITÉ</span>
# <div class="ads"><script>getPub('120x600');</script></div>
# </div>
# </div>
# <div class="col-md-12 col-lg-10">
# <div id="filtre_haut">
# <div class="fDate"><a class="objselect_prevnext objselect_prec" href="/resultat-foot-20-01-2018/" title="Sam 20 janvier"><span aria-hidden="true" class="glyphicon glyphicon-chevron-left"></span></a><div class="objselect "><select class="form-control objselect_liste" name="f_date" onchange="location.href = this.value;"><option value="/resultat-foot-09-01-2018/">Mar 09 janvier</option><option value="/resultat-foot-10-01-2018/">Mer 10 janvier</option><option value="/resultat-foot-11-01-2018/">Jeu 11 janvier</option><option value="/resultat-foot-12-01-2018/">Ven 12 janvier</option><option value="/resultat-foot-13-01-2018/">Sam 13 janvier</option><option value="/resultat-foot-14-01-2018/">Dim 14 janvier</option><option value="/resultat-foot-15-01-2018/">Lun 15 janvier</option><option value="/resultat-foot-16-01-2018/">Mar 16 janvier</option><option value="/resultat-foot-17-01-2018/">Mer 17 janvier</option><option value="/resultat-foot-18-01-2018/">Jeu 18 janvier</option><option value="/resultat-foot-19-01-2018/">Ven 19 janvier</option><option value="/resultat-foot-20-01-2018/">Sam 20 janvier</option><option class="selection" selected="" value="/resultat-foot-21-01-2018/">Dim 21 janvier</option><option value="/resultat-foot-22-01-2018/">Hier</option><option value="/resultat-foot-23-01-2018/">Aujourd'hui</option><option value="/resultat-foot-24-01-2018/">Demain</option><option value="/resultat-foot-25-01-2018/">Jeu 25 janvier</option><option value="/resultat-foot-26-01-2018/">Ven 26 janvier</option><option value="/resultat-foot-27-01-2018/">Sam 27 janvier</option><option value="/resultat-foot-28-01-2018/">Dim 28 janvier</option><option value="/resultat-foot-29-01-2018/">Lun 29 janvier</option><option value="/resultat-foot-30-01-2018/">Mar 30 janvier</option><option value="/resultat-foot-31-01-2018/">Mer 31 janvier</option><option value="/resultat-foot-01-02-2018/">Jeu 01 février</option><option value="/resultat-foot-02-02-2018/">Ven 02 février</option><option value="/resultat-foot-03-02-2018/">Sam 03 février</option><option value="/resultat-foot-04-02-2018/">Dim 04 février</option><option value="/resultat-foot-05-02-2018/">Lun 05 février</option><option value="/resultat-foot-06-02-2018/">Mar 06 février</option></select></div><a class="objselect_prevnext objselect_suiv" href="/resultat-foot-22-01-2018/" title="Hier"><span aria-hidden="true" class="glyphicon glyphicon-chevron-right"></span></a></div>
# <div class="fTermine"></div>
# <div class="fTri"><div class=" objselect_no_nav"><select class="form-control objselect_liste" name="f_tri" onchange="location.href = this.value;"><option class="selection" selected="" value="/resultat-foot-21-01-2018/">Trier</option><option value="/resultat-foot-21-01-2018/asc/">Heure croissante</option><option value="/resultat-foot-21-01-2018/desc/">Heure décroissante</option></select></div></div>
# <div class="clearfix"></div>
# </div>
# <div class="row coucoursPromo">
# <div class="col-xs-12">
# <div class="panel panel-danger">
# <div class="panel-heading">
# <span aria-hidden="true" class="glyphicon glyphicon-info-sign"></span> <h3 class="panel-title"> Saison 5</h3>
# </div>
# <div class="panel-body">
# <!-- strong>On remet les compteurs à zéro !</strong><br/ -->
#                 15ème <a href="/pronostics/"><u>grille</u></a> <span class="hidden-xs"><a href="/pronostics/">à compléter</a></span> pour le <strong>samedi 20 janvier</strong> à 13:00.
#                 <!-- br>
#                 <div style="text-align:center;"><a href="/pronostics/"><img src="/image/concours/lot-saison-3.jpg" style="max-width: 100%;" alt="Lots du concours de pronostics"></a></div -->
# </div>
# </div>
# </div>
# </div>
# <div id="livescore">
# <div class="panel panel-info">
# <div class="panel-heading livescore_head">
# <div class="pLeft">
# <span class="ico_pays ico_pays_76"></span>
# <div class="lienCompetition"><h3 class="panel-title"><a href="/france/ligue-1/">France : Ligue 1</a></h3></div>
# <div class="lienClassement"> - <a class="lienclass" href="/classement-foot/france/classement-ligue-1.html">Classement</a></div>
# </div>
# <div class="pRight">
# <a class="jUpdateCompetMatchsSelect" href="javascript:void(0);" title="Alerte BUT : Recevez une alerte sonore à chaque but !"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="panel-body">
# <table class="table table-striped table-hover"><tr class="" data-matchid="2465121">
# <td class="lm1">15:00</td>
# <td class="lm2 lm2_0" id="status_2465121"><span class="lm2_time">15:00</span>Terminé</td>
# <td class="lm3">
# <a href="/live-score/saint-etienne-nice.html" title="Détail du match : Nice - Saint-Étienne"><span class="lm3_eq1">Nice<span class="hidden-xs"><img alt="Nice" data-src="/image/logo/club/16/nice-logo894.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span></span><span class="lm3_score" id="score_2465121">1 - 0</span><span class="lm3_eq2"><span class="hidden-xs"><img alt="Saint-Étienne" data-src="/image/logo/club/16/saint-etienne-logo901.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span>Saint-Étienne</span></a>
# </td>
# <td class="lm4">
# <a class="MEDLivescoreCheck" href="/live-score/saint-etienne-nice.html#pronostic" title="Pronostic : Nice - Saint-Étienne"><span aria-hidden="true" class="glyphicon glyphicon-check text-success"></span></a>
# <a href="/statistique/nice-contre-saint-etienne.html" title="Statistiques : Nice - Saint-Étienne"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2465121" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr><tr class="" data-matchid="2465118">
# <td class="lm1">17:00</td>
# <td class="lm2 lm2_0" id="status_2465118"><span class="lm2_time">17:00</span>Terminé</td>
# <td class="lm3">
# <a href="/live-score/monaco-metz.html" title="Détail du match : Monaco - Metz"><span class="lm3_eq1">Monaco<span class="hidden-xs"><img alt="Monaco" data-src="/image/logo/club/16/monaco-logo885.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span></span><span class="lm3_score" id="score_2465118">3 - 1</span><span class="lm3_eq2"><span class="hidden-xs"><img alt="Metz" data-src="/image/logo/club/16/metz-logo896.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span>Metz</span></a>
# </td>
# <td class="lm4">
# <a class="MEDLivescoreCheck" href="/live-score/monaco-metz.html#pronostic" title="Pronostic : Monaco - Metz"><span aria-hidden="true" class="glyphicon glyphicon-check text-success"></span></a>
# <a href="/statistique/metz-contre-monaco.html" title="Statistiques : Monaco - Metz"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2465118" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr><tr class="" data-matchid="2465117">
# <td class="lm1">21:00</td>
# <td class="lm2 lm2_0" id="status_2465117"><span class="lm2_time">21:00</span>Terminé</td>
# <td class="lm3">
# <a href="/live-score/lyon-psg.html" title="Détail du match : Lyon - PSG"><span class="lm3_eq1">Lyon<span class="hidden-xs"><img alt="Lyon" data-src="/image/logo/club/16/lyon-logo884.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span></span><span class="lm3_score" id="score_2465117">2 - 1</span><span class="lm3_eq2"><span class="hidden-xs"><img alt="PSG" data-src="/image/logo/club/16/psg-logo886.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span>PSG</span></a>
# </td>
# <td class="lm4">
# <a class="MEDLivescoreCheck" href="/live-score/lyon-psg.html#pronostic" title="Pronostic : Lyon - PSG"><span aria-hidden="true" class="glyphicon glyphicon-check text-success"></span></a>
# <a href="/statistique/lyon-contre-paris-saint-germain.html" title="Statistiques : Lyon - PSG"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2465117" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr> </table>
# </div>
# </div>
# <div class="panel panel-info">
# <div class="panel-heading livescore_head">
# <div class="pLeft">
# <span class="ico_pays ico_pays_68"></span>
# <div class="lienCompetition"><h3 class="panel-title"><a href="/angleterre/barclays-premiership-premier-league/">Angleterre : Premier League</a></h3></div>
# <div class="lienClassement"> - <a class="lienclass" href="/classement-foot/angleterre/classement-barclays-premiership-premier-league.html">Classement</a></div>
# </div>
# <div class="pRight">
# <a class="jUpdateCompetMatchsSelect" href="javascript:void(0);" title="Alerte BUT : Recevez une alerte sonore à chaque but !"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="panel-body">
# <table class="table table-striped table-hover"><tr class="" data-matchid="2463030">
# <td class="lm1">17:00</td>
# <td class="lm2 lm2_0" id="status_2463030"><span class="lm2_time">17:00</span>Terminé</td>
# <td class="lm3">
# <a href="/live-score/southampton-tottenham.html" title="Détail du match : Southampton - Tottenham Hotspur"><span class="lm3_eq1">Southampton<span class="hidden-xs"><img alt="Southampton" data-src="/image/logo/club/16/southampton-logo670.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span></span><span class="lm3_score" id="score_2463030">1 - 1</span><span class="lm3_eq2"><span class="hidden-xs"><img alt="Tottenham Hotspur" data-src="/image/logo/club/16/tottenham-hotspur-logo675.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span>Tottenham Hotspur</span></a>
# </td>
# <td class="lm4">
# <a class="MEDLivescoreCheck" href="/live-score/southampton-tottenham.html#pronostic" title="Pronostic : Southampton - Tottenham Hotspur"><span aria-hidden="true" class="glyphicon glyphicon-check text-success"></span></a>
# <a href="/statistique/southampton-contre-tottenham.html" title="Statistiques : Southampton - Tottenham Hotspur"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2463030" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr> </table>
# </div>
# </div>
# <div class="panel panel-info">
# <div class="panel-heading livescore_head">
# <div class="pLeft">
# <span class="ico_pays ico_pays_176"></span>
# <div class="lienCompetition"><h3 class="panel-title"><a href="/espagne/primera-division/">Espagne : Liga BBVA</a></h3></div>
# <div class="lienClassement"> - <a class="lienclass" href="/classement-foot/espagne/classement-primera-division.html">Classement</a></div>
# </div>
# <div class="pRight">
# <a class="jUpdateCompetMatchsSelect" href="javascript:void(0);" title="Alerte BUT : Recevez une alerte sonore à chaque but !"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="panel-body">
# <table class="table table-striped table-hover"><tr class="" data-matchid="2529438">
# <td class="lm1">12:00</td>
# <td class="lm2 lm2_0" id="status_2529438"><span class="lm2_time">12:00</span>Terminé</td>
# <td class="lm3">
# <a href="/live-score/deportivo-alaves-leganes.html" title="Détail du match : Deportivo Alavés - Leganes"><span class="lm3_eq1">Deportivo Alavés<span class="hidden-xs"><img alt="Deportivo Alavés" data-src="/image/logo/club/16/deportivo-alaves-logo2037.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span></span><span class="lm3_score" id="score_2529438">2 - 2</span><span class="lm3_eq2"><span class="hidden-xs"><img alt="Leganes" data-src="/image/logo/club/16/leganes-logo2053.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span>Leganes</span></a>
# </td>
# <td class="lm4">
# <a class="MEDLivescoreCheck" href="/live-score/deportivo-alaves-leganes.html#pronostic" title="Pronostic : Deportivo Alavés - Leganes"><span aria-hidden="true" class="glyphicon glyphicon-check text-success"></span></a>
# <a href="/statistique/deportivo-alaves-contre-leganes.html" title="Statistiques : Deportivo Alavés - Leganes"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2529438" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr><tr class="" data-matchid="2529430">
# <td class="lm1">16:15</td>
# <td class="lm2 lm2_0" id="status_2529430"><span class="lm2_time">16:15</span>Terminé</td>
# <td class="lm3">
# <a href="/live-score/deportivo-la-corogne-real-madrid.html" title="Détail du match : Real Madrid - Deportivo La Corogne"><span class="lm3_eq1">Real Madrid<span class="hidden-xs"><img alt="Real Madrid" data-src="/image/logo/club/16/real-madrid-logo2016.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span></span><span class="lm3_score" id="score_2529430">7 - 1</span><span class="lm3_eq2"><span class="hidden-xs"><img alt="Deportivo La Corogne" data-src="/image/logo/club/16/deportivo-la-corogne-logo2018.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span>Deportivo La Corogne</span></a>
# </td>
# <td class="lm4">
# <a class="MEDLivescoreCheck" href="/live-score/deportivo-la-corogne-real-madrid.html#pronostic" title="Pronostic : Real Madrid - Deportivo La Corogne"><span aria-hidden="true" class="glyphicon glyphicon-check text-success"></span></a>
# <a href="/statistique/deportivo-la-coruna-contre-real-madrid.html" title="Statistiques : Real Madrid - Deportivo La Corogne"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2529430" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr><tr class="" data-matchid="2529434">
# <td class="lm1">18:30</td>
# <td class="lm2 lm2_0" id="status_2529434"><span class="lm2_time">18:30</span>Terminé</td>
# <td class="lm3">
# <a href="/live-score/real-sociedad-celta-vigo.html" title="Détail du match : Real Sociedad - Celta Vigo"><span class="lm3_eq1">Real Sociedad<span class="hidden-xs"><img alt="Real Sociedad" data-src="/image/logo/club/16/real-sociedad-logo2028.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span></span><span class="lm3_score" id="score_2529434">1 - 2</span><span class="lm3_eq2"><span class="hidden-xs"><img alt="Celta Vigo" data-src="/image/logo/club/16/celta-vigo-logo2033.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span>Celta Vigo</span></a>
# </td>
# <td class="lm4">
# <a class="MEDLivescoreCheck" href="/live-score/real-sociedad-celta-vigo.html#pronostic" title="Pronostic : Real Sociedad - Celta Vigo"><span aria-hidden="true" class="glyphicon glyphicon-check text-success"></span></a>
# <a href="/statistique/celta-vigo-contre-real-sociedad.html" title="Statistiques : Real Sociedad - Celta Vigo"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2529434" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr><tr class="" data-matchid="2529432">
# <td class="lm1">20:45</td>
# <td class="lm2 lm2_0" id="status_2529432"><span class="lm2_time">20:45</span>Terminé</td>
# <td class="lm3">
# <a href="/live-score/betis-seville-barcelone.html" title="Détail du match : Real Bétis - Barcelone"><span class="lm3_eq1">Real Bétis<span class="hidden-xs"><img alt="Real Bétis" data-src="/image/logo/club/16/real-betis-logo2025.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span></span><span class="lm3_score" id="score_2529432">0 - 5</span><span class="lm3_eq2"><span class="hidden-xs"><img alt="Barcelone" data-src="/image/logo/club/16/barcelone-logo2017.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span>Barcelone</span></a>
# </td>
# <td class="lm4">
# <a class="MEDLivescoreCheck" href="/live-score/betis-seville-barcelone.html#pronostic" title="Pronostic : Real Bétis - Barcelone"><span aria-hidden="true" class="glyphicon glyphicon-check text-success"></span></a>
# <a href="/statistique/fc-barcelone-contre-real-betis.html" title="Statistiques : Real Bétis - Barcelone"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2529432" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr> </table>
# </div>
# </div><div id="native_mobile"></div>
# <div class="text-center getPubCentrale"><script>getPubCentrale('mobile');</script></div>
# <div class="panel panel-info">
# <div class="panel-heading livescore_head">
# <div class="pLeft">
# <span class="ico_pays ico_pays_100"></span>
# <div class="lienCompetition"><h3 class="panel-title"><a href="/italie/serie-a/">Italie : Serie A</a></h3></div>
# <div class="lienClassement"> - <a class="lienclass" href="/classement-foot/italie/classement-serie-a.html">Classement</a></div>
# </div>
# <div class="pRight">
# <a class="jUpdateCompetMatchsSelect" href="javascript:void(0);" title="Alerte BUT : Recevez une alerte sonore à chaque but !"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="panel-body">
# <table class="table table-striped table-hover"><tr class="" data-matchid="2538983">
# <td class="lm1">12:30</td>
# <td class="lm2 lm2_0" id="status_2538983"><span class="lm2_time">12:30</span>Terminé</td>
# <td class="lm3">
# <a href="/live-score/atalanta-bergame-naples.html" title="Détail du match : Atalanta - Naples"><span class="lm3_eq1">Atalanta<span class="hidden-xs"><img alt="Atalanta" data-src="/image/logo/club/16/atalanta-logo1255.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span></span><span class="lm3_score" id="score_2538983">0 - 1</span><span class="lm3_eq2"><span class="hidden-xs"><img alt="Naples" data-src="/image/logo/club/16/naples-logo1270.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span>Naples</span></a>
# </td>
# <td class="lm4">
# <a href="/statistique/atalanta-bergame-contre-napoli.html" title="Statistiques : Atalanta - Naples"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2538983" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr><tr class="" data-matchid="2538977">
# <td class="lm1">15:00</td>
# <td class="lm2 lm2_0" id="status_2538977"><span class="lm2_time">15:00</span>Terminé</td>
# <td class="lm3">
# <a href="/live-score/bologne-benevent.html" title="Détail du match : Bologne - Bénévent"><span class="lm3_eq1">Bologne<span class="hidden-xs"><img alt="Bologne" data-src="/image/logo/club/16/bologne-logo1249.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span></span><span class="lm3_score" id="score_2538977">3 - 0</span><span class="lm3_eq2"><span class="hidden-xs"><img alt="Bénévent" data-src="/image/logo/club/16/benevent-logo1302.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span>Bénévent</span></a>
# </td>
# <td class="lm4">
# <a href="/statistique/benevento-contre-bologne.html" title="Statistiques : Bologne - Bénévent"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2538977" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr><tr class="" data-matchid="2538978">
# <td class="lm1">15:00</td>
# <td class="lm2 lm2_0" id="status_2538978"><span class="lm2_time">15:00</span>Terminé</td>
# <td class="lm3">
# <a href="/live-score/chievo-verone-lazio-rome.html" title="Détail du match : Lazio - Chievo"><span class="lm3_eq1">Lazio<span class="hidden-xs"><img alt="Lazio" data-src="/image/logo/club/16/lazio-logo1245.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span></span><span class="lm3_score" id="score_2538978">5 - 1</span><span class="lm3_eq2"><span class="hidden-xs"><img alt="Chievo" data-src="/image/logo/club/16/chievo-logo1248.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span>Chievo</span></a>
# </td>
# <td class="lm4">
# <a href="/statistique/chievo-verone-contre-lazio.html" title="Statistiques : Lazio - Chievo"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2538978" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr><tr class="" data-matchid="2538979">
# <td class="lm1">15:00</td>
# <td class="lm2 lm2_0" id="status_2538979"><span class="lm2_time">15:00</span>Terminé</td>
# <td class="lm3">
# <a href="/live-score/verone-crotone.html" title="Détail du match : Hellas Verona - Crotone"><span class="lm3_eq1">Hellas Verona<span class="hidden-xs"><img alt="Hellas Verona" data-src="/image/logo/club/16/hellas-verona-logo1277.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span></span><span class="lm3_score" id="score_2538979">0 - 3</span><span class="lm3_eq2"><span class="hidden-xs"><img alt="Crotone" data-src="/image/logo/club/16/crotone-logo1280.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span>Crotone</span></a>
# </td>
# <td class="lm4">
# <a href="/statistique/crotone-contre-verone.html" title="Statistiques : Hellas Verona - Crotone"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2538979" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr><tr class="" data-matchid="2538980">
# <td class="lm1">15:00</td>
# <td class="lm2 lm2_0" id="status_2538980"><span class="lm2_time">15:00</span>Terminé</td>
# <td class="lm3">
# <a href="/live-score/fiorentina-sampdoria-de-genes.html" title="Détail du match : Sampdoria - Fiorentina"><span class="lm3_eq1">Sampdoria<span class="hidden-xs"><img alt="Sampdoria" data-src="/image/logo/club/16/sampdoria-logo1247.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span></span><span class="lm3_score" id="score_2538980">3 - 1</span><span class="lm3_eq2"><span class="hidden-xs"><img alt="Fiorentina" data-src="/image/logo/club/16/fiorentina-logo1259.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span>Fiorentina</span></a>
# </td>
# <td class="lm4">
# <a href="/statistique/fiorentina-contre-sampdoria.html" title="Statistiques : Sampdoria - Fiorentina"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2538980" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr><tr class="" data-matchid="2538985">
# <td class="lm1">15:00</td>
# <td class="lm2 lm2_0" id="status_2538985"><span class="lm2_time">15:00</span>Terminé</td>
# <td class="lm3">
# <a href="/live-score/udinese-spal.html" title="Détail du match : Udinese - SPAL"><span class="lm3_eq1">Udinese<span class="hidden-xs"><img alt="Udinese" data-src="/image/logo/club/16/udinese-logo1246.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span></span><span class="lm3_score" id="score_2538985">1 - 1</span><span class="lm3_eq2"><span class="hidden-xs"><img alt="SPAL" data-src="/image/logo/club/16/spal-logo1287.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span>SPAL</span></a>
# </td>
# <td class="lm4">
# <a href="/statistique/spal-contre-udinese.html" title="Statistiques : Udinese - SPAL"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2538985" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr><tr class="" data-matchid="2538986">
# <td class="lm1">15:00</td>
# <td class="lm2 lm2_0" id="status_2538986"><span class="lm2_time">15:00</span>Terminé</td>
# <td class="lm3">
# <a href="/live-score/torino-sassuolo.html" title="Détail du match : Sassuolo - Torino"><span class="lm3_eq1">Sassuolo<span class="hidden-xs"><img alt="Sassuolo" data-src="/image/logo/club/16/sassuolo-logo5681.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span></span><span class="lm3_score" id="score_2538986">1 - 1</span><span class="lm3_eq2"><span class="hidden-xs"><img alt="Torino" data-src="/image/logo/club/16/torino-logo1268.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span>Torino</span></a>
# </td>
# <td class="lm4">
# <a href="/statistique/sassuolo-contre-torino.html" title="Statistiques : Sassuolo - Torino"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2538986" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr><tr class="" data-matchid="2538982">
# <td class="lm1">18:00</td>
# <td class="lm2 lm2_0" id="status_2538982"><span class="lm2_time">18:00</span>Terminé</td>
# <td class="lm3">
# <a href="/live-score/milan-ac-cagliari.html" title="Détail du match : Cagliari - Milan"><span class="lm3_eq1">Cagliari<span class="hidden-xs"><img alt="Cagliari" data-src="/image/logo/club/16/cagliari-logo1256.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span></span><span class="lm3_score" id="score_2538982">1 - 2</span><span class="lm3_eq2"><span class="hidden-xs"><img alt="Milan" data-src="/image/logo/club/16/milan-logo1240.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span>Milan</span></a>
# </td>
# <td class="lm4">
# <a href="/statistique/cagliari-contre-milan-ac.html" title="Statistiques : Cagliari - Milan"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2538982" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr><tr class="" data-matchid="2538984">
# <td class="lm1">20:45</td>
# <td class="lm2 lm2_0" id="status_2538984"><span class="lm2_time">20:45</span>Terminé</td>
# <td class="lm3">
# <a href="/live-score/inter-milan-roma.html" title="Détail du match : Inter Milan - Rome"><span class="lm3_eq1">Inter Milan<span class="hidden-xs"><img alt="Inter Milan" data-src="/image/logo/club/16/inter-milan-logo1244.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span></span><span class="lm3_score" id="score_2538984">1 - 1</span><span class="lm3_eq2"><span class="hidden-xs"><img alt="Rome" data-src="/image/logo/club/16/rome-logo1241.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span>Rome</span></a>
# </td>
# <td class="lm4">
# <a href="/statistique/inter-milan-contre-rome.html" title="Statistiques : Inter Milan - Rome"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2538984" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr> </table>
# </div>
# </div><div class="text-center getPubCentrale"><script>getPubCentrale();</script></div>
# <div class="panel panel-info">
# <div class="panel-heading livescore_head">
# <div class="pLeft">
# <span class="ico_pays ico_pays_80"></span>
# <div class="lienCompetition"><h3 class="panel-title"><a href="/allemagne/bundesliga-1/">Allemagne : Bundesliga</a></h3></div>
# <div class="lienClassement"> - <a class="lienclass" href="/classement-foot/allemagne/classement-bundesliga-1.html">Classement</a></div>
# </div>
# <div class="pRight">
# <a class="jUpdateCompetMatchsSelect" href="javascript:void(0);" title="Alerte BUT : Recevez une alerte sonore à chaque but !"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="panel-body">
# <table class="table table-striped table-hover"><tr class="" data-matchid="2480425">
# <td class="lm1">15:30</td>
# <td class="lm2 lm2_0" id="status_2480425"><span class="lm2_time">15:30</span>Terminé</td>
# <td class="lm3">
# <a href="/live-score/bayern-munich-werder-breme.html" title="Détail du match : Bayern Munich - Werder Brême"><span class="lm3_eq1">Bayern Munich<span class="hidden-xs"><img alt="Bayern Munich" data-src="/image/logo/club/16/bayern-munich-logo961.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span></span><span class="lm3_score" id="score_2480425">4 - 2</span><span class="lm3_eq2"><span class="hidden-xs"><img alt="Werder Brême" data-src="/image/logo/club/16/werder-breme-logo960.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span>Werder Brême</span></a>
# </td>
# <td class="lm4">
# <a class="MEDLivescoreCheck" href="/live-score/bayern-munich-werder-breme.html#pronostic" title="Pronostic : Bayern Munich - Werder Brême"><span aria-hidden="true" class="glyphicon glyphicon-check text-success"></span></a>
# <a href="/statistique/bayern-munich-contre-werder-breme.html" title="Statistiques : Bayern Munich - Werder Brême"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2480425" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr><tr class="" data-matchid="2480430">
# <td class="lm1">18:00</td>
# <td class="lm2 lm2_0" id="status_2480430"><span class="lm2_time">18:00</span>Terminé</td>
# <td class="lm3">
# <a href="/live-score/schalke-04-hanovre-96.html" title="Détail du match : Schalke 04 - Hannovre 96"><span class="lm3_eq1">Schalke 04<span class="hidden-xs"><img alt="Schalke 04" data-src="/image/logo/club/16/schalke-04-logo966.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span></span><span class="lm3_score" id="score_2480430">1 - 1</span><span class="lm3_eq2"><span class="hidden-xs"><img alt="Hannovre 96" data-src="/image/logo/club/16/hannovre-96-logo972.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span>Hannovre 96</span></a>
# </td>
# <td class="lm4">
# <a class="MEDLivescoreCheck" href="/live-score/schalke-04-hanovre-96.html#pronostic" title="Pronostic : Schalke 04 - Hannovre 96"><span aria-hidden="true" class="glyphicon glyphicon-check text-success"></span></a>
# <a href="/statistique/hanovre-96-contre-schalke-04.html" title="Statistiques : Schalke 04 - Hannovre 96"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2480430" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr> </table>
# </div>
# </div>
# <div class="panel panel-info">
# <div class="panel-heading livescore_head">
# <div class="pLeft">
# <span class="ico_pays ico_pays_156"></span>
# <div class="lienCompetition"><h3 class="panel-title"><a href="/portugal/bwin-liga/">Portugal : Liga Sagres</a></h3></div>
# <div class="lienClassement"> - <a class="lienclass" href="/classement-foot/portugal/classement-bwin-liga.html">Classement</a></div>
# </div>
# <div class="pRight">
# <a class="jUpdateCompetMatchsSelect" href="javascript:void(0);" title="Alerte BUT : Recevez une alerte sonore à chaque but !"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="panel-body">
# <table class="table table-striped table-hover"><tr class="" data-matchid="2501952">
# <td class="lm1">17:00</td>
# <td class="lm2 lm2_0" id="status_2501952"><span class="lm2_time">17:00</span>Terminé</td>
# <td class="lm3">
# <a href="/live-score/pacos-de-ferreira-desportivo-aves.html" title="Détail du match : Desportivo Aves - Paços de Ferreira"><span class="lm3_eq1">Desportivo Aves<span class="hidden-xs"><img alt="Desportivo Aves" data-src="/image/logo/club/16/desportivo-aves-logo1702.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span></span><span class="lm3_score" id="score_2501952">0 - 2</span><span class="lm3_eq2"><span class="hidden-xs"><img alt="Paços de Ferreira" data-src="/image/logo/club/16/pacos-de-ferreira-logo1693.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span>Paços de Ferreira</span></a>
# </td>
# <td class="lm4">
# <a href="/statistique/aves-contre-pacos-de-ferreira.html" title="Statistiques : Desportivo Aves - Paços de Ferreira"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2501952" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr><tr class="" data-matchid="2501954">
# <td class="lm1">17:00</td>
# <td class="lm2 lm2_0" id="status_2501954"><span class="lm2_time">17:00</span>Terminé</td>
# <td class="lm3">
# ...
# </td>
# <td class="lm4">
# <a href="/statistique/mexico-u20-contre-nicaragua-u20-13794.html" title="Statistiques : Nicaragua U20 - Mexico U20"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2683694" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr> </table>
# </div>
# </div>
# <div class="panel panel-info">
# <div class="panel-heading livescore_head">
# <div class="pLeft">
# <span class="ico_pays ico_pays_5"></span>
# <div class="lienCompetition"><h3 class="panel-title"><a href="/amerique-du-sud/sudamericano-u20-femenino/">Amérique du Sud : Sudamericano U20 Femenino</a></h3></div>
# <div class="lienClassement"> - <a class="lienclass" href="/classement-foot/amerique-du-sud/classement-sudamericano-u20-femenino.html">Classement</a></div>
# </div>
# <div class="pRight">
# <a class="jUpdateCompetMatchsSelect" href="javascript:void(0);" title="Alerte BUT : Recevez une alerte sonore à chaque but !"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="panel-body">
# <table class="table table-striped table-hover"><tr class="" data-matchid="2702059">
# <td class="lm1">01:15</td>
# <td class="lm2 lm2_0" id="status_2702059"><span class="lm2_time">01:15</span>Terminé</td>
# <td class="lm3">
# <a href="/live-score/venezuela-u20-chile-u20.html" title="Détail du match : Venezuela U20 - Chile U20"><span class="lm3_eq1">Venezuela U20<span class="hidden-xs"><img alt="Venezuela U20" data-src="/image/logo/club/16/venezuela-u20-logo20979.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span></span><span class="lm3_score" id="score_2702059">1 - 0</span><span class="lm3_eq2"><span class="hidden-xs"><img alt="Chile U20" data-src="/image/logo/club/16/chile-u20-logo20981.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span>Chile U20</span></a>
# </td>
# <td class="lm4">
# <a href="/statistique/chile-u20-contre-venezuela-u20.html" title="Statistiques : Venezuela U20 - Chile U20"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2702059" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr><tr class="" data-matchid="2702026">
# <td class="lm1">23:00</td>
# <td class="lm2 lm2_0" id="status_2702026"><span class="lm2_time">23:00</span>Terminé</td>
# <td class="lm3">
# <a href="/live-score/argentina-u20-paraguay-u20.html" title="Détail du match : Argentina U20 - Paraguay U20"><span class="lm3_eq1">Argentina U20<span class="hidden-xs"><img alt="Argentina U20" data-src="/image/logo/club/16/argentina-u20-logo7093.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span></span><span class="lm3_score" id="score_2702026">0 - 3</span><span class="lm3_eq2"><span class="hidden-xs"><img alt="Paraguay U20" data-src="/image/logo/club/16/paraguay-u20-logo20985.png?v2" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span>Paraguay U20</span></a>
# </td>
# <td class="lm4">
# <a href="/statistique/argentina-u20-contre-paraguay-u20.html" title="Statistiques : Argentina U20 - Paraguay U20"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2702026" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr> </table>
# </div>
# </div>
# <div class="panel panel-info">
# <div class="panel-heading livescore_head">
# <div class="pLeft">
# <span class="ico_pays ico_pays_6"></span>
# <div class="lienCompetition"><h3 class="panel-title"><a href="/oceanie/ofc-champions-league/">Océanie : OFC Champions League</a></h3></div>
# <div class="lienClassement"> - <a class="lienclass" href="/classement-foot/oceanie/classement-ofc-champions-league.html">Classement</a></div>
# </div>
# <div class="pRight">
# <a class="jUpdateCompetMatchsSelect" href="javascript:void(0);" title="Alerte BUT : Recevez une alerte sonore à chaque but !"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="panel-body">
# <table class="table table-striped table-hover"><tr class="" data-matchid="2696591">
# <td class="lm1">00:00</td>
# <td class="lm2 lm2_0" id="status_2696591"><span class="lm2_time">00:00</span>Terminé</td>
# <td class="lm3">
# <a href="/live-score/tupapa-maraerenga-lupe-ole-soaga.html" title="Détail du match : Tupapa Maraerenga - Lupe Ole Soaga"><span class="lm3_eq1">Tupapa Maraerenga<span class="hidden-xs"><img alt="Tupapa Maraerenga" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span></span><span class="lm3_score" id="score_2696591">1 - 0</span><span class="lm3_eq2"><span class="hidden-xs"><img alt="Lupe Ole Soaga" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span>Lupe Ole Soaga</span></a>
# </td>
# <td class="lm4">
# <a href="/statistique/lupe-ole-soaga-contre-tupapa-maraerenga.html" title="Statistiques : Tupapa Maraerenga - Lupe Ole Soaga"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2696591" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr><tr class="" data-matchid="2696590">
# <td class="lm1">03:00</td>
# <td class="lm2 lm2_0" id="status_2696590"><span class="lm2_time">03:00</span>Terminé</td>
# <td class="lm3">
# <a href="/live-score/pago-youth-veitongo.html" title="Détail du match : Veitongo - Pago Youth"><span class="lm3_eq1">Veitongo<span class="hidden-xs"><img alt="Veitongo" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span></span><span class="lm3_score" id="score_2696590">1 - 1</span><span class="lm3_eq2"><span class="hidden-xs"><img alt="Pago Youth" height="16" src="/image/logo/club/16/equipe-logodefaut.png?v2" width="16"/></span>Pago Youth</span></a>
# </td>
# <td class="lm4">
# <a href="/statistique/pago-youth-contre-veitongo.html" title="Statistiques : Veitongo - Pago Youth"><span aria-hidden="true" class="glyphicon glyphicon-stats text-primary"></span></a>
# <a class="text-muted jUpdateMatchsSelect" href="javascript:void(0);" id="alerte_but_2696590" title="Alerte BUT"><span aria-hidden="true" class="glyphicon glyphicon-bell"></span></a>
# </td>
# </tr>
# </table>
# </div>
# </div>
# <div id="native_mobile"></div>
# <div class="text-center getPubCentrale"><script>getPubCentrale('mobile');</script></div><div class="text-center getPubCentrale"><script>getPubCentrale();</script></div>
# </div>
# <div id="bloc_liste_info"></div>
# <input name="f_refresh_score" type="hidden" value=""/>
# <audio id="player_but">
# <source src="/audio/but.mp3" type="audio/mpeg">
# </source></audio>
# <script>
# var liste_cote = new Array();
# </script>
# <!-- DEBUT TABOOLA -->
# <div>
# <div id="taboola-below-article-thumbnails-rev-share"></div>
# <script>
#         window._taboola = window._taboola || [];
#         _taboola.push({
#             mode: 'thumbnails-a',
#             container: 'taboola-below-article-thumbnails-rev-share',
#             placement: 'Below Article Thumbnails Rev Share',
#             target_type: 'mix'
#         });
#     </script>
# </div>
# <!-- FIN TABOOLA -->
# </div>
# </div>
# </div>
# <div class="col-md-4 col-lg-3 col-right">
# <div id="colonne_droite">
# <div class="row">
# <div class="col-xs-12">
# <div class="panel panel-info MEDpanelconf">
# <div class="panel-heading">
# <span aria-hidden="true" class="glyphicon glyphicon-share"></span> <h3 class="panel-title"> Partagez</h3>
# </div>
# <div class="panel-body">
# <div class="sharing">
# <div class="socialNetwork">
# <button class="btn btn-sharing btn-fb" type="button"><i class="fa fa-facebook left"></i> <span class="MEDsharing">Facebook</span></button>
# <button class="btn btn-sharing btn-tw" type="button"><i class="fa fa-twitter left"></i> <span class="MEDsharing">Twitter</span></button>
# <button class="btn btn-sharing btn-gplus" type="button"><i class="fa fa-google-plus left"></i> <span class="MEDsharing">Google +</span></button>
# <div class="clearfix"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="bloc_coldroite"><div class="panel panel-info MEDpanelconf" id="tux_liste_colr_bookmaker">
# <div class="panel-heading">
# <h3 class="panel-title"><a href="/info/bonus-paris-sportifs.html">Pariez en ligne</a></h3>
# <div class="txtbonus">Bonus offert</div>
# </div>
# <div class="panel-body">
# <div class="list-group groupMatchLink">
# <a class="list-group-item book" href="/tux/coldroite/top/pmu.html" rel="nofollow" target="_blank" title="PMU">
# <div>
# <span class="logo"><img alt="PMU" src="/image/bookmaker/h25-pmu.png?v3"/></span>
# <h4 class="txtpariez"><span class="label label-default">Pariez</span></h4>
# <span class="txtmontant">100€</span>
# <div style="clear:both;"></div>
# </div>
# </a>
# <a class="list-group-item book" href="/tux/coldroite/top/zebet.html" rel="nofollow" target="_blank" title="ZEbet">
# <div>
# <span class="logo"><img alt="ZEbet" src="/image/bookmaker/h25-zebet.png?v3"/></span>
# <h4 class="txtpariez"><span class="label label-default">Pariez</span></h4>
# <span class="txtmontant">150€</span>
# <div style="clear:both;"></div>
# </div>
# </a>
# <a class="list-group-item book" href="/tux/coldroite/top/betclic.html" rel="nofollow" target="_blank" title="Betclic">
# <div>
# <span class="logo"><img alt="Betclic" src="/image/bookmaker/h25-betclic.png?v3"/></span>
# <h4 class="txtpariez"><span class="label label-default">Pariez</span></h4>
# <span class="txtmontant">100€</span>
# <div style="clear:both;"></div>
# </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="ads"><script>getPub('300x600');</script></div>
# <div class="panel panel-info MEDpanelconf">
# <div class="panel-heading">
# <span aria-hidden="true" class="glyphicon glyphicon-comment"></span> <h3 class="panel-title">Discussions les plus populaires</h3>
# </div>
# <div class="panel-body">
# <div class="list-group groupMatchLink" id="lgCommentairePopulaire">
# <a class="list-group-item " href="/tennis/#commentaires">Tennis en direct</a>
# <a class="list-group-item " href="/hockey/#commentaires">Hockey en direct</a>
# <a class="list-group-item " href="/basket/#commentaires">Basket en direct</a>
# </div>
# </div>
# </div>
# <!-- cache 2018-01-23 03:44:10 -->
# <!-- DEBUT PUB -->
# <div class="ads"><script>getPub('300x250');</script></div>
# <!-- FIN PUB -->
# <div class="panel panel-info">
# <div class="panel-heading">
# <span aria-hidden="true" class="glyphicon glyphicon-info-sign"></span> <h3 class="panel-title">Infos</h3>
# </div>
# <div class="panel-body">
# <p>Vous consultez actuellement la page :<br/>Livescore du dimanche 21 janvier 2018<br/><br/>Liste des <strong>résultats foot</strong> du 21-01-2018, au total il y a 1201 matchs de football pour cette date.</p>
# </div>
# </div>
# <div style="width:300px; height:500px; margin:0 auto 20px;">
# <div class="fb-page" data-adapt-container-width="true" data-hide-cover="false" data-href="https://www.facebook.com/matchendirect.fr/" data-show-facepile="true" data-small-header="true" data-tabs="timeline" data-width="300"><blockquote cite="https://www.facebook.com/matchendirect.fr/" class="fb-xfbml-parse-ignore"><a href="https://www.facebook.com/matchendirect.fr/">matchendirect.fr</a></blockquote></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <footer>
# <div class="container">
# <div>
# <div class="row">
# <div class="col-md-3">
# <h3 class="sr-only">A PROPOS DE NOUS</h3>
# <a href="/" title="Match En Direct"><img alt="Match En Direct" height="35" src="/image/commun/logo/match-en-direct-football-live.png" width="130"/></a>
# <br/><br/>
# <p>Voir un match de football en direct ? Gratuitement regarder tous les scores de foot en direct live des matchs de foot dans le monde entier.</p>
# </div>
# <div class="col-md-6">
# <h3>LIENS UTILES</h3>
# <div class="row margin-bottom-30px">
# <div class="col-xs-4">
# <ul class="list-unstyled footer-nav">
# <li><i aria-hidden="true" class="fa fa-caret-right"></i> <a href="/contact.html">Contact</a></li>
# <li><i aria-hidden="true" class="fa fa-caret-right"></i> <a href="/plan/">Plan du site</a></li>
# <li><i aria-hidden="true" class="fa fa-caret-right"></i> <a href="/guide/">Guide</a></li>
# <li><i aria-hidden="true" class="fa fa-caret-right"></i> <a href="/mentions-legales/">Mentions légales</a></li>
# <li><i aria-hidden="true" class="fa fa-caret-right"></i> <a href="/partenaires/">Partenaires</a></li>
# </ul>
# </div>
# <div class="col-xs-4">
# <ul class="list-unstyled footer-nav">
# <li><i aria-hidden="true" class="fa fa-caret-right"></i> <a href="/live-score/">En live</a></li>
# <li><i aria-hidden="true" class="fa fa-caret-right"></i> <a href="/prochain-match-en-live/">Calendrier</a></li>
# <li><i aria-hidden="true" class="fa fa-caret-right"></i> <a href="/classement-foot/">Classements</a></li>
# <li><i aria-hidden="true" class="fa fa-caret-right"></i> <a href="/statistique/">Statistiques</a></li>
# </ul>
# </div>
# <div class="col-xs-4">
# <ul class="list-unstyled footer-nav">
# <li><i aria-hidden="true" class="fa fa-caret-right"></i> <a href="/info/turf-paris-hippiques.html" title="Pronostics Turf">Turf</a></li>
# <li><i aria-hidden="true" class="fa fa-caret-right"></i> <a href="/info/jouer-au-poker.html" title="Poker en ligne">Poker</a></li>
# <li><i aria-hidden="true" class="fa fa-caret-right"></i> <a href="/info/streaming-football.html" title="Streaming Football">Streaming</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-md-3">
# <div class="row">
# <div class="col-xs-6 col-md-12 social-connect">
# <h3>RESTEZ CONNECTÉ</h3>
# <ul class="list-inline social-icons">
# <li><a class="facebook-bg" href="https://www.facebook.com/matchendirect.fr/"><i class="fa fa-facebook"></i></a></li>
# <li><a class="twitter-bg" href="https://twitter.com/#!/MatchEnDirectFr"><i class="fa fa-twitter"></i></a></li>
# <li><a class="rss-bg" href="/rss/"><i class="fa fa-rss"></i></a></li>
# </ul>
# </div>
# <div class="col-xs-6 col-md-12 social-connect">
# <h3>NOS APPLICATIONS</h3>
# <ul class="list-inline social-icons">
# <li><a class="apple-bg" href="/info/application-iphone-resultats-foot-en-direct.html" title="Application iPhone"><i class="fa fa-apple"></i></a></li>
# <li><a class="android-bg" href="/info/application-android-resultats-foot-en-direct.html" title="Application Android"><i class="fa fa-android"></i></a></li>
# <li><a class="linkedin-bg" href="/info/application-windows-phone-resultats-foot-en-direct.html" title="Application Windows Phone"><i class="fa fa-windows"></i></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <script>
#         getPub('high_impact');
#         getPub('skin');
#         getPub('mobile_interstitial');
#     </script>
# <a class="btn btn-primary btn-lg back-to-top" data-placement="left" data-toggle="tooltip" href="#" id="back-to-top" role="button" title="Cliquez pour retourner en haut de la page"><span class="glyphicon glyphicon-chevron-up"></span></a>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js"></script>
# <script src="https://ajax.googleapis.com/ajax/libs/jqueryui/1.12.1/jquery-ui.min.js"></script>
# <script crossorigin="anonymous" integrity="sha384-Tc5IQib027qvyjSMfHjOMaLkfuWVxZxUPnCJA7l2mCWNIpG9mGCD8wGNIcPD7Txa" src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/notify/0.4.2/notify.min.js"></script>
# <script src="/html_include/js/commun_bottom.js?v411"></script>
# <!-- web1.mathendirect.fr / 2018-01-23 03:44:36 -->
# </body>
# </html>

# %%
# page.find('div', {'class':'events'}).findAll('a')

#s1=page.findAll('div',{"class": 'panel-body'})
#s2=s1.findAll('table',{'class':'table table striped table-hover'})
# s=page.findAll('td',{'class':'panel-body table table-striped table-hover lm1'})
PageTime=page.find_all('div', class_ = 'panel-body')
#print(s[1])
#print(s[1].table.td)
Time=PageTime[1].find_all('td',class_="lm1")
print(t[0].text)
# Out:
# 15:00

# %%
PageAdversaire = page.find_all('div', class_ = 'panel-body')
PageAdversaire1 = PageAdversaire[1].find_all('a',href="/live-score/saint-etienne-nice.html")
print(PageAdversaire1[0].find_all('span',class_='lm3_eq1')[0].text)      
print(PageAdversaire1[0].find_all('span',class_='lm3_score')[0].text)      
print(PageAdversaire1[0].find_all('span',class_='lm3_eq2')[0].text)
# Out:
# Nice
# 1 - 0
# Saint-Étienne
