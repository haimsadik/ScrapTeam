# %%
#KAGGLE
import pandas as pd
import sqlite3

#Se connecte à la sqlite
con = sqlite3.connect("/Users/Martin/Documents/ENSAE/Scrape/database.sqlite")



l_var = ["Country","League","Match","Player","Player_Attributes","sqlite_sequence","Team","Team_Attributes"]

# %%
##il me manque "le nom de la database" je comprends pas trop, go sur 
## How to open and convert sqlite database to pandas dataframe sur stackoverflow tu verras
##la je vais y aller bourrin, normalement mon code se comprend
# en gros il y a plusieurs bases la dedans ??????


####
#####
####  JEUX FIFA DONNEES


## tu dois faire à tout prix la mise à jour de Pandas pour avoir 
# Jupyterlab qui est en gros Jupyter en 2 fois mieux plus ergo

# ca c'est plus perso mais je te conseille de nettoyer ton ordi aussi bien d'un point de vue donnée
# que d'un point de vue plus "terre à terre" hahahaha

## Merci Selim

# %%
l_df = [] 

for var in l_var : 
    l_df.append(pd.read_sql_query("SELECT * FROM " + var, con))

# %%
for df in l_df :
    print(df.head())

# %%
for df,x in zip(l_df,l_var) :
    print(x +"_____" +x)
    print()
    print(df.shape)
    print("\n")
    print(df.describe())
    print("\n")
    print(df.info())
    
    
    print("\n")
    print("\n")
    print("\n")
    print("\n")

# %%
print(l_df)
# Out:
# [       id         name
# 0       1      Belgium
# 1    1729      England
# 2    4769       France
# 3    7809      Germany
# 4   10257        Italy
# 5   13274  Netherlands
# 6   15722       Poland
# 7   17642     Portugal
# 8   19694     Scotland
# 9   21518        Spain
# 10  24558  Switzerland,        id  country_id                      name
# 0       1           1    Belgium Jupiler League
# 1    1729        1729    England Premier League
# 2    4769        4769            France Ligue 1
# 3    7809        7809     Germany 1. Bundesliga
# 4   10257       10257             Italy Serie A
# 5   13274       13274    Netherlands Eredivisie
# 6   15722       15722        Poland Ekstraklasa
# 7   17642       17642  Portugal Liga ZON Sagres
# 8   19694       19694   Scotland Premier League
# 9   21518       21518           Spain LIGA BBVA
# 10  24558       24558  Switzerland Super League,           id  country_id  league_id     season  stage                 date  \
# ...
