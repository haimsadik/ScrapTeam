# %%
import xml.etree.ElementTree
import os
import lxml

# %%
#path='Exemple de fichier pour base de test - f24-24-2016-853285-eventdetails_test_hackathon_2.xml'
path='XPSG - ressources disponibles/Exemple de fichier pour base de test - f24-24-2016-853285-eventdetails_test_hackathon_2.xml'
xml = lxml.etree.parse(path)
root=xml.getroot()
#Je cherche la liste des matchs
listematchs=os.listdir('XPSG - ressources disponibles/French Ligue One 20162017 season - Match Day 1- 19')

#for match in listematchs:

# %%
for event in root.iter('Event'):
    #Je garde en mémoire les résultats. pertinennts pour event par. event. cocernant. le. joueur d'etude. 
    a1= [x for x in event.attrib.items()][1][1]
    a2= [x for x in event.attrib.items()][2][1]
    a3= [x for x in event.attrib.items()][3][1]
    a4= [x for x in event.attrib.items()][4][1]
    a5= [x for x in event.attrib.items()][5][1]
    a6= [x for x in event.attrib.items()][6][1]
    a7= [x for x in event.attrib.items()][7][1]
    a8= [x for x in event.attrib.items()][8][1]
    a9= [x for x in event.attrib.items()][9][1]
    a10=[x for x in event.attrib.items()][10][1]
    
    
    
    #print([x for x in event.attrib.items()][10][1])
print(a1,a10)
# Out:
# 769 70.9

# %%
#for match in listematchs:
match=listematchs[1]
print(match)
tree=lxml.etree.parse('XPSG - ressources disponibles/French Ligue One 20162017 season - Match Day 1- 19/'+str(match))
root2=tree.getroot()

for event2 in root2.iter('Event'):
    print(event2.attrib)
# Out:
# f24-24-2016-853200-eventdetails.xml
# {'id': '1351945131', 'event_id': '1', 'type_id': '34', 'period_id': '16', 'min': '0', 'sec': '0', 'team_id': '429', 'outcome': '1', 'x': '0.0', 'y': '0.0', 'timestamp': '2016-09-25T13:09:51.778', 'last_modified': '2016-09-25T14:00:21', 'version': '1474808420132'}
# {'id': '2023813393', 'event_id': '1', 'type_id': '34', 'period_id': '16', 'min': '0', 'sec': '0', 'team_id': '152', 'outcome': '1', 'x': '0.0', 'y': '0.0', 'timestamp': '2016-09-25T13:17:41.173', 'last_modified': '2016-09-25T14:03:01', 'version': '1474808581096'}
# {'id': '1590075911', 'event_id': '2', 'type_id': '32', 'period_id': '1', 'min': '0', 'sec': '0', 'team_id': '429', 'outcome': '1', 'x': '0.0', 'y': '0.0', 'timestamp': '2016-09-25T14:00:09.440', 'last_modified': '2016-09-25T14:00:10', 'version': '1474808409444'}
# ...
